# %% [markdown]
# <a href="https://colab.research.google.com/github/IbrahimSayyad2001/Assignment-python-1/blob/main/matplotlib2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py'>

# %%
tod=['morning','afternoon','evening','night']
press=[150,110,170,100]

# %%
plt.figure(figsize=(18,5))
plt.plot(tod,press,color='k',linestyle='-',label='compressed air ',marker='+');
plt.legend()
plt.xlabel('PARTS OF DAYS')
plt.ylabel('PRESSURISED AIR IN BAR')
# Out:
# Text(0, 0.5, 'PRESSURISED AIR IN BAR')

# %%
plt.figure(figsize=(18,5))
plt.bar(tod,press,color=['k','g','r','c'],linestyle='--',label='compressed air ');
plt.legend()
plt.xlabel('PARTS OF DAYS')
plt.ylabel('PRESSURISED AIR IN BAR')
# Out:
# Text(0, 0.5, 'PRESSURISED AIR IN BAR')

# %%
plt.plot?

# %%
plt.figure(figsize=(10,5))
plt.plot(tod,press,color='k',linestyle='-',label='compressed air ',marker='+');
plt.plot(tod,[85,90,115,105],color='g',linestyle='--',label='compressed air ',marker='^');
plt.legend()
plt.xlabel('PARTS OF DAY')
plt.ylabel('PRESSURISED AIR IN BAR')
plt.grid()

# %%
import numpy as np
a=np.random.random(50)
a
# Out:
# array([0.27484945, 0.23651353, 0.02255939, 0.0316658 , 0.70106395,
#        0.45692751, 0.68821359, 0.81170184, 0.01988418, 0.12928722,
#        0.2456001 , 0.22383762, 0.29644958, 0.62337343, 0.10862064,
#        0.10188525, 0.15562388, 0.31559895, 0.51094724, 0.53088521,
#        0.49238877, 0.17539385, 0.89958106, 0.2582647 , 0.41488963,
#        0.96478625, 0.59687441, 0.80468738, 0.6831527 , 0.61811467,
#        0.71980552, 0.73185763, 0.99776978, 0.31742312, 0.97601511,
#        0.49297117, 0.35345326, 0.46860382, 0.43795198, 0.32259652,
#        0.87513084, 0.19896837, 0.63144337, 0.60325009, 0.74529888,
#        0.18378063, 0.59734874, 0.24871023, 0.19911524, 0.6001973 ])

# %%
plt.scatter(range(1,51),a)

# %%
plt.scatter(range(1,51),np.linspace(1,10))

# %%
per=np.random.randint(42,100,100)
per
# Out:
# array([60, 90, 46, 75, 74, 67, 67, 49, 96, 94, 95, 86, 46, 43, 94, 58, 75,
#        56, 79, 70, 94, 96, 63, 51, 54, 46, 42, 87, 61, 84, 96, 59, 59, 59,
#        81, 97, 80, 61, 74, 62, 58, 86, 62, 55, 89, 52, 78, 47, 42, 97, 77,
#        98, 62, 55, 97, 58, 66, 68, 59, 63, 43, 55, 52, 48, 58, 44, 48, 55,
#        78, 52, 67, 83, 59, 73, 97, 62, 75, 57, 87, 61, 92, 70, 72, 67, 97,
#        58, 66, 68, 68, 51, 51, 69, 83, 87, 60, 53, 76, 47, 59, 64])

# %%
plt.hist(per,bins=[42,50,65,85,90])
# Out:
# (array([13., 37., 29.,  7.]),
#  array([42., 50., 65., 85., 90.]),
#  <BarContainer object of 4 artists>)

# %%
plt.pie(press,autopct='%.f%%',labels=tod)
plt.show()

# %%
plt.pie(press,autopct='%.f%%',labels=tod, explode=[0.1,0.2,0.2,0.1])
plt.show()
plt.savefig('prss.png',dpi=300)

# %%
a
# Out:
# array([0.27484945, 0.23651353, 0.02255939, 0.0316658 , 0.70106395,
#        0.45692751, 0.68821359, 0.81170184, 0.01988418, 0.12928722,
#        0.2456001 , 0.22383762, 0.29644958, 0.62337343, 0.10862064,
#        0.10188525, 0.15562388, 0.31559895, 0.51094724, 0.53088521,
#        0.49238877, 0.17539385, 0.89958106, 0.2582647 , 0.41488963,
#        0.96478625, 0.59687441, 0.80468738, 0.6831527 , 0.61811467,
#        0.71980552, 0.73185763, 0.99776978, 0.31742312, 0.97601511,
#        0.49297117, 0.35345326, 0.46860382, 0.43795198, 0.32259652,
#        0.87513084, 0.19896837, 0.63144337, 0.60325009, 0.74529888,
#        0.18378063, 0.59734874, 0.24871023, 0.19911524, 0.6001973 ])

# %%
plt.boxplot(a)
plt.show()

# %%
a.min()
# Out:
# 0.01988417853841884

# %%
a.max()
# Out:
# 0.9977697763562711

# %%
a.mean()
# Out:
# 0.4619062669064815
