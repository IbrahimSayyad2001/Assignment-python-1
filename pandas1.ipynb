# %% [markdown]
# <a href="https://colab.research.google.com/github/IbrahimSayyad2001/Assignment-python-1/blob/main/pandas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/sample_data/california_housing_train.csv')
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
df.head(2)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0

# %%
df.tail(4)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0

# %%
df.shape
# Out:
# (17000, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
df.columns=range(9)
df
# Out:
#             0      1     2       3       4       5      6       7         8
# 0     -114.31  34.19  15.0  5612.0  1283.0  1015.0  472.0  1.4936   66900.0
# 1     -114.47  34.40  19.0  7650.0  1901.0  1129.0  463.0  1.8200   80100.0
# 2     -114.56  33.69  17.0   720.0   174.0   333.0  117.0  1.6509   85700.0
# 3     -114.57  33.64  14.0  1501.0   337.0   515.0  226.0  3.1917   73400.0
# 4     -114.57  33.57  20.0  1454.0   326.0   624.0  262.0  1.9250   65500.0
# ...       ...    ...   ...     ...     ...     ...    ...     ...       ...
# 16995 -124.26  40.58  52.0  2217.0   394.0   907.0  369.0  2.3571  111400.0
# 16996 -124.27  40.69  36.0  2349.0   528.0  1194.0  465.0  2.5179   79000.0
# 16997 -124.30  41.84  17.0  2677.0   531.0  1244.0  456.0  3.0313  103600.0
# 16998 -124.30  41.80  19.0  2672.0   552.0  1298.0  478.0  1.9797   85800.0
# 16999 -124.35  40.54  52.0  1820.0   300.0   806.0  270.0  3.0147   94600.0
#
# [17000 rows x 9 columns]

# %%
df.columns = ['longitude', 'latitude', 'housing_median_age', 'total_rooms',
       'total_bedrooms', 'population', 'households', 'median_income',
       'median_house_value']

# %%
df.rename(columns={'housing_median_age':'h_m_age'},inplace=True)
df.columns
# Out:
# Index(['longitude', 'latitude', 'h_m_age', 'total_rooms', 'total_bedrooms',
#        'population', 'households', 'median_income', 'median_house_value'],
#       dtype='object')

# %%
df.longitude.head()
# Out:
# 0   -114.31
# 1   -114.47
# 2   -114.56
# 3   -114.57
# 4   -114.57
# Name: longitude, dtype: float64

# %%
df.h_m_age
# Out:
# 0        15.0
# 1        19.0
# 2        17.0
# 3        14.0
# 4        20.0
#          ...
# 16995    52.0
# 16996    36.0
# 16997    17.0
# 16998    19.0
# 16999    52.0
# Name: h_m_age, Length: 17000, dtype: float64

# %%
df['h_m_age']
# Out:
# 0        15.0
# 1        19.0
# 2        17.0
# 3        14.0
# 4        20.0
#          ...
# 16995    52.0
# 16996    36.0
# 16997    17.0
# 16998    19.0
# 16999    52.0
# Name: h_m_age, Length: 17000, dtype: float64

# %%
df[['h_m_age']]
# Out:
#        h_m_age
# 0         15.0
# 1         19.0
# 2         17.0
# 3         14.0
# 4         20.0
# ...        ...
# 16995     52.0
# 16996     36.0
# 16997     17.0
# 16998     19.0
# 16999     52.0
#
# [17000 rows x 1 columns]

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'h_m_age', 'total_rooms', 'total_bedrooms',
#        'population', 'households', 'median_income', 'median_house_value'],
#       dtype='object')

# %%
df[['h_m_age','longitude']]
# Out:
#        h_m_age  longitude
# 0         15.0    -114.31
# 1         19.0    -114.47
# 2         17.0    -114.56
# 3         14.0    -114.57
# 4         20.0    -114.57
# ...        ...        ...
# 16995     52.0    -124.26
# 16996     36.0    -124.27
# 16997     17.0    -124.30
# 16998     19.0    -124.30
# 16999     52.0    -124.35
#
# [17000 rows x 2 columns]

# %%
df[['h_m_age','longitude']].head(50)
# Out:
#     h_m_age  longitude
# 0      15.0    -114.31
# 1      19.0    -114.47
# 2      17.0    -114.56
# 3      14.0    -114.57
# 4      20.0    -114.57
# 5      29.0    -114.58
# 6      25.0    -114.58
# 7      41.0    -114.59
# 8      34.0    -114.59
# 9      46.0    -114.60
# 10     16.0    -114.60
# 11     21.0    -114.60
# 12     48.0    -114.61
# 13     31.0    -114.61
# 14     15.0    -114.63
# 15     17.0    -114.65
# 16     28.0    -114.65
# 17     21.0    -114.65
# 18     17.0    -114.66
# 19     17.0    -114.67
# 20     20.0    -114.68
# 21     24.0    -114.73
# 22     20.0    -114.94
# 23     15.0    -114.98
# 24     18.0    -115.22
# 25     34.0    -115.32
# 26     30.0    -115.37
# 27     14.0    -115.37
# 28     32.0    -115.37
# 29     23.0    -115.37
# 30     38.0    -115.38
# 31     35.0    -115.38
# 32     16.0    -115.39
# 33     19.0    -115.40
# 34     19.0    -115.40
# 35     29.0    -115.41
# 36     33.0    -115.46
# 37     21.0    -115.48
# 38     15.0    -115.48
# ...

# %%
df[['h_m_age','longitude']].sample(5)
# Out:
#        h_m_age  longitude
# 6306      42.0    -118.25
# 2647      26.0    -117.67
# 13792     32.0    -122.01
# 7257      40.0    -118.34
# 8181       5.0    -118.44

# %%
df.loc[100:110,:]
# Out:
#      longitude  latitude  h_m_age  total_rooms  total_bedrooms  population  \
# 100    -115.59     32.79      8.0       2183.0           307.0      1000.0
# 101    -115.59     32.69     30.0        935.0           177.0       649.0
# 102    -115.60     33.20     37.0        709.0           187.0       390.0
# 103    -115.60     32.87      3.0       1629.0           317.0      1005.0
# 104    -115.62     33.04     20.0       1121.0           244.0       766.0
# 105    -115.62     33.04     17.0       1009.0           231.0       745.0
# 106    -115.64     32.80     23.0       1228.0           235.0       569.0
# 107    -115.69     32.79     18.0       1564.0           340.0      1161.0
# 108    -115.72     32.75     16.0        348.0            99.0       123.0
# 109    -115.73     33.36     19.0        749.0           238.0       476.0
# 110    -115.73     33.35     23.0       1586.0           448.0       338.0
#
#      households  median_income  median_house_value
# ...

# %%
df.loc[1:10,'total_rooms':'population'	]
# Out:
#     total_rooms  total_bedrooms  population
# 1        7650.0          1901.0      1129.0
# 2         720.0           174.0       333.0
# 3        1501.0           337.0       515.0
# 4        1454.0           326.0       624.0
# 5        1387.0           236.0       671.0
# 6        2907.0           680.0      1841.0
# 7         812.0           168.0       375.0
# 8        4789.0          1175.0      3134.0
# 9        1497.0           309.0       787.0
# 10       3741.0           801.0      2434.0
