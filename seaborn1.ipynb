# %% [markdown]
# <a href="https://colab.research.google.com/github/IbrahimSayyad2001/Assignment-python-1/blob/main/seaborn1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

# %%
t=sns.load_dataset('titanic')
t.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
t.shape
# Out:
# (891, 15)

# %%
t.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
t.sex
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: sex, Length: 891, dtype: object

# %%
g=t.sex.value_counts()

# %%
g.index
# Out:
# Index(['male', 'female'], dtype='object')

# %%
g.values
# Out:
# array([577, 314])

# %%
import matplotlib.pyplot as plt
plt.pie(g.values,labels=g.index,autopct='%.f%%',explode=[0,0.2])
plt.show()

# %%
sns.countplot(x='sex',data=t)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='class',data=t,hue='sex',palette='rainbow')
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.stripplot(x='class',y='age',data=t,hue='sex')
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.countplot(x='survived',data=t,hue='class')
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(x='survived',data=t,hue='sex')
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.pairplot(t[['pclass','age','fare']])

# %%
ir=sns.load_dataset('iris')
sns.pairplot(ir,hue='species')

# %%
ir=sns.load_dataset('iris')
ir
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.histplot(x='age',data=t,hue='class')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(x='age',data=t,hue='class',bins=[20,42,56,70,86])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.lineplot(x='sex',y='age',data=t)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.barplot(x='class',y='sex',data=t,hue='age')
# Out:
# <Axes: xlabel='class', ylabel='sex'>

# %%
sns.boxplot(t)
# Out:
# <Axes: >

# %%
sns.boxplot(x='class',y='age',data=t,hue='sex')
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.kdeplot(ir)
# Out:
# <Axes: ylabel='Density'>

# %%
p=sns.load_dataset('tips')
p
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
p.sex
# Out:
# 0      Female
# 1        Male
# 2        Male
# 3        Male
# 4      Female
#         ...
# 239      Male
# 240    Female
# 241      Male
# 242      Male
# 243    Female
# Name: sex, Length: 244, dtype: category
# Categories (2, object): ['Male', 'Female']

# %%
dc=p['day'].value_counts()
dc
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
dc.index
# Out:
# CategoricalIndex(['Sat', 'Sun', 'Thur', 'Fri'], categories=['Thur', 'Fri', 'Sat', 'Sun'], ordered=False, dtype='category')

# %%
dc.values
# Out:
# array([87, 76, 62, 19])

# %%
plt.pie(dc,labels=dc.index,autopct='%.f%%')
plt.title('distribution of days')
plt.show()

# %%
s=p['sex'].value_counts()
s
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
s.index
# Out:
# CategoricalIndex(['Male', 'Female'], categories=['Male', 'Female'], ordered=False, dtype='category')

# %%
s.values
# Out:
# array([157,  87])

# %%
plt.pie(s,labels=s.index,autopct='%f.%%')
plt.title('distribution according to sex')
plt.show()

# %%
p
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.stripplot(x='day',y='sex',data=p,hue='tip')
# Out:
# <Axes: xlabel='day', ylabel='sex'>

# %%
sns.countplot(x="day",data=p,hue="sex",palette='plasma')
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(x="total_bill",data=p,hue="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='count'>

# %%
sns.countplot(x='sex',data=p,hue='smoker',palette='magma')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.pairplot(p)

# %%
sns.pairplot(t,hue='sex')

# %%
sns.histplot(x='total_bill',data=p,hue='sex',bins=[10,20,25,30])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.lineplot(x='sex',y='smoker',data=p)
# Out:
# <Axes: xlabel='sex', ylabel='smoker'>

# %%
p
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.lineplot(x='day',y='sex',data=p,hue='time')
# Out:
# <Axes: xlabel='day', ylabel='sex'>

# %%
sns.barplot(x='sex',y='smoker',data=p,hue='day')
# Out:
# <Axes: xlabel='sex', ylabel='smoker'>

# %%
p
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.boxplot(x='sex',y='day',data=p,hue='time')
# Out:
# <Axes: xlabel='sex', ylabel='day'>

# %%
sns.kdeplot(p)
# Out:
# <Axes: ylabel='Density'>
