# %% [markdown]
# <a href="https://colab.research.google.com/github/IbrahimSayyad2001/Assignment-python-1/blob/main/pandas_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
p=sns.load_dataset('penguins')
p
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
p.species.unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
list(p.groupby('species'))
# Out:
# [('Adelie',
#       species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
#   0    Adelie  Torgersen            39.1           18.7              181.0
#   1    Adelie  Torgersen            39.5           17.4              186.0
#   2    Adelie  Torgersen            40.3           18.0              195.0
#   3    Adelie  Torgersen             NaN            NaN                NaN
#   4    Adelie  Torgersen            36.7           19.3              193.0
#   ..      ...        ...             ...            ...                ...
#   147  Adelie      Dream            36.6           18.4              184.0
#   148  Adelie      Dream            36.0           17.8              195.0
#   149  Adelie      Dream            37.8           18.1              193.0
#   150  Adelie      Dream            36.0           17.1              187.0
#   151  Adelie      Dream            41.5           18.5              201.0
#
#        body_mass_g     sex
# ...

# %%
p.groupby('species').get_group('Chinstrap')
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152  Chinstrap  Dream            46.5           17.9              192.0
# 153  Chinstrap  Dream            50.0           19.5              196.0
# 154  Chinstrap  Dream            51.3           19.2              193.0
# 155  Chinstrap  Dream            45.4           18.7              188.0
# 156  Chinstrap  Dream            52.7           19.8              197.0
# ..         ...    ...             ...            ...                ...
# 215  Chinstrap  Dream            55.8           19.8              207.0
# 216  Chinstrap  Dream            43.5           18.1              202.0
# 217  Chinstrap  Dream            49.6           18.2              193.0
# 218  Chinstrap  Dream            50.8           19.0              210.0
# 219  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex
# 152       3500.0  Female
# 153       3900.0    Male
# ...

# %%
p.groupby('species').get_group('Chinstrap').iloc[1:4,3:6]
# Out:
#      bill_depth_mm  flipper_length_mm  body_mass_g
# 153           19.5              196.0       3900.0
# 154           19.2              193.0       3650.0
# 155           18.7              188.0       3525.0

# %%
p.groupby('species')['bill_depth_mm'].mean()
# Out:
# species
# Adelie       18.346358
# Chinstrap    18.420588
# Gentoo       14.982114
# Name: bill_depth_mm, dtype: float64

# %%
p.groupby('species')['bill_depth_mm'].plot(kind='bar',color='g')
# Out:
# species
# Adelie       Axes(0.125,0.11;0.775x0.77)
# Chinstrap    Axes(0.125,0.11;0.775x0.77)
# Gentoo       Axes(0.125,0.11;0.775x0.77)
# Name: bill_depth_mm, dtype: object

# %%
p.groupby(['island','species'])[['body_mass_g','bill_length_mm']].agg([max,min,np.mean])
# Out:
#                     body_mass_g                      bill_length_mm        \
#                             max     min         mean            max   min
# island    species
# Biscoe    Adelie         4775.0  2850.0  3709.659091           45.6  34.5
#           Gentoo         6300.0  3950.0  5076.016260           59.6  40.9
# Dream     Adelie         4650.0  2900.0  3688.392857           44.1  32.1
#           Chinstrap      4800.0  2700.0  3733.088235           58.0  40.9
# Torgersen Adelie         4700.0  2900.0  3706.372549           46.0  33.5
#
#
#                           mean
# island    species
# Biscoe    Adelie     38.975000
#           Gentoo     47.504878
# Dream     Adelie     38.501786
#           Chinstrap  48.833824
# Torgersen Adelie     38.950980

# %%
p.sort_values(by='bill_depth_mm',ignore_index=True)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Gentoo     Biscoe            42.9           13.1              215.0
# 1    Gentoo     Biscoe            46.1           13.2              211.0
# 2    Gentoo     Biscoe            44.9           13.3              213.0
# 3    Gentoo     Biscoe            43.3           13.4              209.0
# 4    Gentoo     Biscoe            42.0           13.5              210.0
# ..      ...        ...             ...            ...                ...
# 339  Adelie  Torgersen            38.6           21.2              191.0
# 340  Adelie      Dream            42.3           21.2              191.0
# 341  Adelie  Torgersen            46.0           21.5              194.0
# 342  Adelie  Torgersen             NaN            NaN                NaN
# 343  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g     sex
# 0         5000.0  Female
# 1         4500.0  Female
# ...

# %%
p.sort_index()
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...
