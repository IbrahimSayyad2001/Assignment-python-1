# %% [markdown]
# <a href="https://colab.research.google.com/github/IbrahimSayyad2001/Assignment-python-1/blob/main/pandas2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
st=pd.read_csv('/content/StudentsPerformance.csv')

# %%
st.to_excel('ibrahim.xlsx')
st
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
st.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
st['math score'].dtypes
# Out:
# dtype('int64')

# %%
st['new math score']=st['math score'].astype('float')

# %%
st.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score', 'new math score'],
#       dtype='object')

# %%
st['race/ethnicity'].unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
st[['race/ethnicity', 'parental level of education', 'lunch']].value_counts()
# Out:
# race/ethnicity  parental level of education  lunch
# group C         associate's degree           standard        56
#                 some college                 standard        46
# group D         some college                 standard        41
# group C         high school                  standard        41
# group D         some high school             standard        37
# group B         high school                  standard        32
# group D         associate's degree           standard        29
#                 high school                  standard        28
# group E         some college                 standard        28
# group B         some high school             standard        28
# group C         some high school             standard        28
# group B         associate's degree           standard        27
# group E         associate's degree           standard        26
# group D         some college                 free/reduced    26
# ...

# %%
st.gender.map({'male':1,'female':2})
# Out:
# 0      2
# 1      2
# 2      2
# 3      1
# 4      1
#       ..
# 995    2
# 996    1
# 997    2
# 998    2
# 999    2
# Name: gender, Length: 1000, dtype: int64

# %%
st.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score', 'new math score'],
#       dtype='object')

# %%
st.drop(columns=[  'writing score', 'new math score'])
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score
# 0                      none          72             72
# ...

# %%
st.insert(3,column='good',value=range(1000))

# %%
st.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'good',
#        'lunch', 'test preparation course', 'math score', 'reading score',
#        'writing score', 'new math score'],
#       dtype='object')
